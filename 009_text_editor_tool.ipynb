# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 8192,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):                                                                                                                                             
      return {                                                                                                                                                                 
          "type": "text_editor_20250728",                                                                                                                                    
          "name": "str_replace_based_edit_tool",                                                                                                                               
      }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.

    Then create a ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and a test file. Let me start by viewing the main.py file to see what's already there.
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (Gregory-Leibniz series) which is a simple method to calculate pi:
# Now let's create a test file to verify our implementation:
# Perfect! Let me verify the files were created correctly:
# Excellent! I've successfully created:
#
# ## 1. **./main.py** - Contains the `calculate_pi()` function
#
# The function uses **Machin's formula** for calculating pi, which is:
# ```
# π/4 = 4*arctan(1/5) - arctan(1/239)
# ```
#
# This formula converges much faster than simpler methods like the Leibniz series. The implementation:
# - Uses Taylor series expansion to calculate arctangent values
# - Includes early termination for efficiency when changes become negligible
# - Rounds the result to the specified precision (5 decimal places by default)
# - The expected result is **3.14159** (pi to 5 decimal places)
#
# ## 2. **./test.py** - Comprehensive test suite
#
# The test file includes 5 different tests:
# 1. **Test 1**: Verifies pi is calculated correctly to 5 decimal places
# 2. **Test 2**: Tests calculation with 3 decimal places
# 3. **Test 3**: Tests calculation with 2 decimal places
# 4. **Test 4**: Verifies the result is within acceptable tolerance of the actual pi value
# 5. **Test 5**: Checks that the function returns a numeric type
#
# You can run the tests by executing:
# ```bash
# python test.py
# ```
#
# And run the main program with:
# ```bash
# python main.py
# ```
#
# The implementation should accurately calculate pi as **3.14159** when using 5 decimal places of precision.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n\n    Then create a ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and a test file. Let me start by viewing the main.py file to see what's already there.", type='text'),
#    ToolUseBlock(id='toolu_01DZRUbFmKZhdMeVy2w1kgZU', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01DZRUbFmKZhdMeVy2w1kgZU',
#     'content': '"1: def main():\\n2:     print(\\"Hello, world!\\")\\n3: \\n4: \\n5: if __name__ == \\"__main__\\":\\n6:     main()\\n7: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (Gregory-Leibniz series) which is a simple method to calculate pi:", type='text'),
#    ToolUseBlock(id='toolu_0148j6EBSypGhDHeBHYxvSKD', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def main():\n    print("Hello, world!")', 'new_str': 'def calculate_pi(precision=5):\n    """\n    Calculate pi to a specified number of decimal digits using the Machin formula.\n    The Machin formula converges much faster than the Leibniz formula.\n    \n    Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    \n    Args:\n        precision: Number of decimal digits to calculate (default: 5)\n    \n    Returns:\n        float: Approximation of pi\n    """\n    # We need extra iterations for accuracy\n    # Using more terms than needed to ensure accuracy at the desired precision\n    iterations = 10 ** (precision + 2)\n    \n    def arctan(x, num_terms):\n        """Calculate arctan using Taylor series expansion"""\n        result = 0\n        x_squared = x * x\n        x_power = x\n        \n        for n in range(num_terms):\n            sign = (-1) ** n\n            result += sign * x_power / (2 * n + 1)\n            x_power *= x_squared\n            \n            # Early termination if change is negligible\n            if abs(x_power / (2 * n + 3)) < 10 ** -(precision + 3):\n                break\n        \n        return result\n    \n    # Using Machin\'s formula for faster convergence\n    pi_approx = 4 * (4 * arctan(1/5, 1000) - arctan(1/239, 1000))\n    \n    return round(pi_approx, precision)\n\n\ndef main():\n    pi_value = calculate_pi(5)\n    print(f"Pi to 5 decimal places: {pi_value}")\n    print(f"Actual value of pi:      3.14159...")'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_0148j6EBSypGhDHeBHYxvSKD',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create a test file to verify our implementation:", type='text'),
#    ToolUseBlock(id='toolu_014u53H596KRYLx5wyfPTyoN', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import math\nfrom main import calculate_pi\n\n\ndef test_calculate_pi():\n    """Test the calculate_pi function"""\n    \n    # Test 1: Calculate pi to 5 decimal places\n    print("Test 1: Calculate pi to 5 decimal places")\n    calculated_pi = calculate_pi(5)\n    actual_pi = round(math.pi, 5)\n    print(f"  Calculated: {calculated_pi}")\n    print(f"  Actual:     {actual_pi}")\n    print(f"  Match: {calculated_pi == actual_pi}")\n    assert calculated_pi == actual_pi, f"Expected {actual_pi}, got {calculated_pi}"\n    print("  ✓ PASSED\\n")\n    \n    # Test 2: Calculate pi to 3 decimal places\n    print("Test 2: Calculate pi to 3 decimal places")\n    calculated_pi_3 = calculate_pi(3)\n    actual_pi_3 = round(math.pi, 3)\n    print(f"  Calculated: {calculated_pi_3}")\n    print(f"  Actual:     {actual_pi_3}")\n    print(f"  Match: {calculated_pi_3 == actual_pi_3}")\n    assert calculated_pi_3 == actual_pi_3, f"Expected {actual_pi_3}, got {calculated_pi_3}"\n    print("  ✓ PASSED\\n")\n    \n    # Test 3: Calculate pi to 2 decimal places\n    print("Test 3: Calculate pi to 2 decimal places")\n    calculated_pi_2 = calculate_pi(2)\n    actual_pi_2 = round(math.pi, 2)\n    print(f"  Calculated: {calculated_pi_2}")\n    print(f"  Actual:     {actual_pi_2}")\n    print(f"  Match: {calculated_pi_2 == actual_pi_2}")\n    assert calculated_pi_2 == actual_pi_2, f"Expected {actual_pi_2}, got {calculated_pi_2}"\n    print("  ✓ PASSED\\n")\n    \n    # Test 4: Verify the value is close to pi\n    print("Test 4: Verify calculated value is within acceptable range")\n    calculated_pi_full = calculate_pi(5)\n    difference = abs(calculated_pi_full - math.pi)\n    print(f"  Calculated: {calculated_pi_full}")\n    print(f"  Math.pi:    {math.pi}")\n    print(f"  Difference: {difference}")\n    print(f"  Within tolerance: {difference < 0.00001}")\n    assert difference < 0.00001, f"Difference too large: {difference}"\n    print("  ✓ PASSED\\n")\n    \n    # Test 5: Check that it returns a numeric value\n    print("Test 5: Check return type")\n    result = calculate_pi(5)\n    print(f"  Type: {type(result)}")\n    print(f"  Is numeric: {isinstance(result, (int, float))}")\n    assert isinstance(result, (int, float)), f"Expected numeric type, got {type(result)}"\n    print("  ✓ PASSED\\n")\n    \n    print("=" * 50)\n    print("ALL TESTS PASSED! ✓")\n    print("=" * 50)\n\n\nif __name__ == "__main__":\n    test_calculate_pi()\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_014u53H596KRYLx5wyfPTyoN',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_011f78CvkprEFscxWJrKnqNx', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_011f78CvkprEFscxWJrKnqNx',
#     'content': '"1: def calculate_pi(precision=5):\\n2:     \\"\\"\\"\\n3:     Calculate pi to a specified number of decimal digits using the Machin formula.\\n4:     The Machin formula converges much faster than the Leibniz formula.\\n5:     \\n6:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n7:     \\n8:     Args:\\n9:         precision: Number of decimal digits to calculate (default: 5)\\n10:     \\n11:     Returns:\\n12:         float: Approximation of pi\\n13:     \\"\\"\\"\\n14:     # We need extra iterations for accuracy\\n15:     # Using more terms than needed to ensure accuracy at the desired precision\\n16:     iterations = 10 ** (precision + 2)\\n17:     \\n18:     def arctan(x, num_terms):\\n19:         \\"\\"\\"Calculate arctan using Taylor series expansion\\"\\"\\"\\n20:         result = 0\\n21:         x_squared = x * x\\n22:         x_power = x\\n23:         \\n24:         for n in range(num_terms):\\n25:             sign = (-1) ** n\\n26:             result += sign * x_power / (2 * n + 1)\\n27:             x_power *= x_squared\\n28:             \\n29:             # Early termination if change is negligible\\n30:             if abs(x_power / (2 * n + 3)) < 10 ** -(precision + 3):\\n31:                 break\\n32:         \\n33:         return result\\n34:     \\n35:     # Using Machin\'s formula for faster convergence\\n36:     pi_approx = 4 * (4 * arctan(1/5, 1000) - arctan(1/239, 1000))\\n37:     \\n38:     return round(pi_approx, precision)\\n39: \\n40: \\n41: def main():\\n42:     pi_value = calculate_pi(5)\\n43:     print(f\\"Pi to 5 decimal places: {pi_value}\\")\\n44:     print(f\\"Actual value of pi:      3.14159...\\")\\n45: \\n46: \\n47: if __name__ == \\"__main__\\":\\n48:     main()\\n49: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Excellent! I've successfully created:\n\n## 1. **./main.py** - Contains the `calculate_pi()` function\n\nThe function uses **Machin's formula** for calculating pi, which is:\n```\nπ/4 = 4*arctan(1/5) - arctan(1/239)\n```\n\nThis formula converges much faster than simpler methods like the Leibniz series. The implementation:\n- Uses Taylor series expansion to calculate arctangent values\n- Includes early termination for efficiency when changes become negligible\n- Rounds the result to the specified precision (5 decimal places by default)\n- The expected result is **3.14159** (pi to 5 decimal places)\n\n## 2. **./test.py** - Comprehensive test suite\n\nThe test file includes 5 different tests:\n1. **Test 1**: Verifies pi is calculated correctly to 5 decimal places\n2. **Test 2**: Tests calculation with 3 decimal places\n3. **Test 3**: Tests calculation with 2 decimal places\n4. **Test 4**: Verifies the result is within acceptable tolerance of the actual pi value\n5. **Test 5**: Checks that the function returns a numeric type\n\nYou can run the tests by executing:\n```bash\npython test.py\n```\n\nAnd run the main program with:\n```bash\npython main.py\n```\n\nThe implementation should accurately calculate pi as **3.14159** when using 5 decimal places of precision.", type='text')]}]
